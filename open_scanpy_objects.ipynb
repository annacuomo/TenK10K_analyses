# %%
import scanpy as sc
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-pej2ah00 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.

# %%
my_file = "/share/ScratchGeneral/anncuo/OneK1K/expression_objects/sce1.h5ad"
# my_file = "/share/ScratchGeneral/anncuo/OneK1K/expression_objects/sce22.h5ad"

# %%
adata = sc.read(my_file)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1272489 × 302
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'pool', 'individual', 'percent.mt', 'latent', 'nCount_SCT', 'nFeature_SCT', 'cell_type'
#     var: 'sct.detection_rate', 'sct.gmean', 'sct.variance', 'sct.residual_variance', 'sct.variable'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
adata.obs
# Out:
#                     orig.ident  nCount_RNA  nFeature_RNA  pool individual  \
# AAACCTGAGAATGTTG-1           0       401.0           123     0    691_692
# AAACCTGAGAGAACAG-1           0       182.0            89     0    693_694
# AAACCTGAGCATGGCA-1           0       187.0            57     0    688_689
# AAACCTGAGTATTGGA-1           0       657.0           185     0    683_684
# AAACCTGAGTGTCCCG-1           0       257.0            94     0    684_685
# ...                        ...         ...           ...   ...        ...
# TTTGTCATCCGCTGTT-9           0       325.0           102     8    796_797
# TTTGTCATCCGTTGTC-9           0       368.0           106     8    800_801
# TTTGTCATCGCCGTGA-9           0       328.0            94     8    821_822
# TTTGTCATCGCGGATC-9           0       339.0           124     8    840_841
# TTTGTCATCTCGTATT-9           0       369.0           143     8    821_822
#
#                     percent.mt  latent  nCount_SCT  nFeature_SCT  cell_type
# AAACCTGAGAATGTTG-1    1.451409       0       281.0           122          1
# AAACCTGAGAGAACAG-1    3.700691       0       198.0            89         14
# AAACCTGAGCATGGCA-1    3.386373       0       209.0            57          0
# AAACCTGAGTATTGGA-1    2.626147       0       249.0           113          5
# AAACCTGAGTGTCCCG-1    4.911875       0       230.0            94          3
# ...                        ...     ...         ...           ...        ...
# TTTGTCATCCGCTGTT-9    3.118305       0       253.0           102         13
# TTTGTCATCCGTTGTC-9    2.147175       0       253.0           105          0
# TTTGTCATCGCCGTGA-9    2.314197       0       233.0            92          0
# TTTGTCATCGCGGATC-9    3.432701       0       255.0           123          0
# TTTGTCATCTCGTATT-9    2.309307       0       291.0           142          3
#
# [1272489 rows x 10 columns]

# %%
adata.var
# Out:
#                 sct.detection_rate  sct.gmean  sct.variance  \
# AL590822.1                0.001200   0.000839      0.001248
# AL591806.1                0.000011   0.000008      0.000011
# HES4                      0.013809   0.012661      0.055939
# ISG15                     0.226770   0.206337      0.884674
# TNFRSF18                  0.038506   0.030501      0.071765
# ...                            ...        ...           ...
# RP4-803J11.2              0.001161   0.000807      0.001174
# RP5-827C21.6              0.000454   0.000316      0.000466
# RP11-544D21.2             0.000407   0.000283      0.000409
# RP11-518L10.5             0.000825   0.000573      0.000832
# RP11-488L18.10            0.033346   0.023821      0.035441
#
#                 sct.residual_variance  sct.variable
# AL590822.1                   1.131237             1
# AL591806.1                   1.469688             1
# HES4                         1.950852             1
# ISG15                        1.904921             1
# TNFRSF18                     1.661204             1
# ...                               ...           ...
# RP4-803J11.2                 1.177608             1
# RP5-827C21.6                 1.146583             1
# RP11-544D21.2                1.188024             1
# RP11-518L10.5                1.134904             1
# RP11-488L18.10               1.167066             1
#
# [302 rows x 5 columns]

# %%
sc.pp.log1p(adata)
# Out:
# /share/ScratchGeneral/anncuo/jupyter/conda_notebooks/envs/cellregmap_notebook/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:352: RuntimeWarning: invalid value encountered in log1p
#   np.log1p(X, out=X)

# %%
adata.X.shape
# Out:
# (1272489, 302)

# %%
gene = "HES4"

# %%
adata[:, ['HES4']].X.shape
# Out:
# (1272489, 1)
