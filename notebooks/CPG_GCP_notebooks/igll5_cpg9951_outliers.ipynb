# %%
import hail as hl
from bokeh.io import show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
mt = hl.read_matrix_table('gs://cpg-tob-wgs-test/v0/IGLL5_50K_window.mt')
mt.count()
# Out:
# (51990, 1061)

# %%
mt = hl.read_matrix_table('gs://cpg-tob-wgs-test/mt/v7.mt')
mt.count()
# Out:
# Initializing Hail with default parameters...
# 2022-09-12 06:27:43 WARN  NativeCodeLoader:60 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2022-09-12 06:27:44 WARN  Hail:43 - This Hail JAR was compiled for Spark 3.1.3, running with Spark 3.1.2.
#   Compatibility is not guaranteed.
# 2022-09-12 06:27:45 WARN  Utils:69 - Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Running on Apache Spark version 3.1.2
# SparkUI available at http://annas-notebook.australia-southeast1-a.c.notebooks-314505.internal:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.97-937922d7f46c
# LOGGING: writing to /home/jupyter/hail-20220912-0627-0.2.97-937922d7f46c.log
# (175993904, 24)

# %%
mt = mt.filter_rows(mt.locus.contig == 'chr22')
mt.count()

# %%
mt = mt.filter_rows(hl.len(hl.or_else(mt.filters, hl.empty_set(hl.tstr))) == 0)
mt.count()

# %%
mt = hl.variant_qc(mt)
mt.rows().show()
# Out:
# [Stage 2:============================================>              (3 + 1) / 4]
# +----------------+------------+------+-------------------+------------+
# | locus          | alleles    | rsid | n_unsplit_alleles | mixed_site |
# +----------------+------------+------+-------------------+------------+
# | locus<GRCh38>  | array<str> | str  |             int32 |       bool |
# +----------------+------------+------+-------------------+------------+
# | chr22:1        | ["N"]      | NA   |                 1 |      False |
# | chr22:10510001 | ["G"]      | NA   |                 1 |      False |
# | chr22:10510021 | ["T"]      | NA   |                 1 |      False |
# | chr22:10510064 | ["T"]      | NA   |                 1 |      False |
# | chr22:10510066 | ["A"]      | NA   |                 1 |      False |
# | chr22:10510069 | ["T"]      | NA   |                 1 |      False |
# | chr22:10510075 | ["T"]      | NA   |                 1 |      False |
# ...

# %%
mt = mt.filter_rows(hl.len(mt.alleles)==2)
mt.count()
# Out:
# [Stage 4:======================================================>(243 + 1) / 244]
# (1294574, 1061)

# %%
mt = mt.filter_rows(hl.is_snp(mt.alleles[0], mt.alleles[1]))
mt.count()
# Out:
# [Stage 5:======================================================>(243 + 1) / 244]
# (806978, 1061)

# %%
mt.rows().show()
# Out:
# [Stage 7:>                                                          (0 + 1) / 1]
# +----------------+------------+------+-------------------+------------+
# | locus          | alleles    | rsid | n_unsplit_alleles | mixed_site |
# +----------------+------------+------+-------------------+------------+
# | locus<GRCh38>  | array<str> | str  |             int32 |       bool |
# +----------------+------------+------+-------------------+------------+
# | chr22:10510445 | ["A","G"]  | NA   |                 2 |      False |
# | chr22:10510838 | ["A","G"]  | NA   |                 2 |      False |
# | chr22:10511351 | ["A","C"]  | NA   |                 2 |      False |
# | chr22:10511521 | ["C","T"]  | NA   |                 2 |      False |
# | chr22:10511641 | ["A","G"]  | NA   |                 2 |      False |
# | chr22:10511678 | ["A","C"]  | NA   |                 2 |      False |
# | chr22:10513066 | ["C","A"]  | NA   |                 2 |      False |
# ...

# %%
mt.s.show(5)
# Out:
# [Stage 0:>                                                          (0 + 2) / 4]
# +-----------+
# | s         |
# +-----------+
# | str       |
# +-----------+
# | "CPG1057" |
# | "CPG1065" |
# | "CPG1073" |
# | "CPG1081" |
# | "CPG1099" |
# +-----------+
# showing top 5 rows

# %%
# from cpg_utils.hail_batch import dataset_path
# from cloudpathlib import AnyPath
import pandas as pd

# %%
# gene_file = 'scrna-seq/grch38_association_files/gene_location_files/GRCh38_geneloc_chr22.tsv'
# gene_df = pd.read_csv(AnyPath(dataset_path(gene_file)), sep='\t', index_col=0)

# %%
gene_file = 'gs://cpg-tob-wgs-test/scrna-seq/grch38_association_files/gene_location_files/GRCh38_geneloc_chr22.tsv'
gene_df = pd.read_csv(gene_file, sep='\t', index_col=0)

# %%
# gene_name = 'IGLL5'
gene_name = 'VPREB3'
window_size = 50000

# %%
interval_start = int(gene_df[gene_df['gene_name'] == gene_name]['start']) - int(window_size)
interval_end = int(gene_df[gene_df['gene_name'] == gene_name]['end']) + int(window_size)

# %%
chrom = 22

# %%
# clip to chromosome boundaries
left_boundary = max(1, interval_start)
right_boundary = min(interval_end, hl.get_reference('GRCh38').lengths[f'chr{chrom}'])
# Out:
# Initializing Hail with default parameters...
# 2022-09-27 00:49:03 WARN  NativeCodeLoader:60 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2022-09-27 00:49:05 WARN  Hail:43 - This Hail JAR was compiled for Spark 3.1.3, running with Spark 3.1.2.
#   Compatibility is not guaranteed.
# Running on Apache Spark version 3.1.2
# SparkUI available at http://annas-notebook.australia-southeast1-a.c.notebooks-314505.internal:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.97-937922d7f46c
# LOGGING: writing to /home/jupyter/hail-20220927-0048-0.2.97-937922d7f46c.log

# %%
# get gene-specific genomic interval
gene_interval = f'chr{chrom}:{left_boundary}-{right_boundary}'
gene_interval
# Out:
# 'chr22:23702743-23804425'

# %%
mt = hl.filter_intervals(mt,[hl.parse_locus_interval(gene_interval, reference_genome='GRCh38')],)
mt.count()
# Out:
# [Stage 10:>                                                         (0 + 2) / 2]
# (2244, 1061)

# %%
mt.variant_qc.AF.show()
# Out:
# [Stage 11:=============================>                            (1 + 1) / 2]
# +----------------+------------+---------------------+
# | locus          | alleles    | <expr>              |
# +----------------+------------+---------------------+
# | locus<GRCh38>  | array<str> | array<float64>      |
# +----------------+------------+---------------------+
# | chr22:22837795 | ["G","T"]  | [9.89e-01,1.09e-02] |
# | chr22:22837799 | ["C","A"]  | [9.68e-01,3.23e-02] |
# | chr22:22837803 | ["G","A"]  | [9.96e-01,4.03e-03] |
# | chr22:22837805 | ["C","A"]  | [9.96e-01,4.07e-03] |
# | chr22:22837806 | ["T","A"]  | [9.97e-01,3.09e-03] |
# | chr22:22837807 | ["C","A"]  | [9.72e-01,2.79e-02] |
# | chr22:22837825 | ["A","C"]  | [8.33e-01,1.67e-01] |
# | chr22:22837828 | ["C","A"]  | [9.91e-01,9.05e-03] |
# | chr22:22837830 | ["G","C"]  | [9.94e-01,6.41e-03] |
# | chr22:22837836 | ["T","A"]  | [9.95e-01,4.76e-03] |
# +----------------+------------+---------------------+
# ...

# %%
# sample = 'CPG9951'
sample = 'CPG34'

# %%
donor_mt = mt.filter_cols(mt.s == sample)

# %%
donor_mt = donor_mt.filter_rows(hl.agg.any(donor_mt.GT.is_non_ref()))

# %%
donor_mt.count()
# Out:
# [Stage 13:>                                                         (0 + 2) / 2]
# (148, 1)

# %%
import numpy as np
np.nanmin(donor_mt.variant_qc.AF[1].collect())
# Out:
# [Stage 15:>                                                         (0 + 2) / 2]
# 0.20168067226890757

# %%
donor_mt0 = donor_mt.filter_rows(donor_mt.variant_qc.AF[1] < 0.05)

# %%
donor_mt0.variant_qc.AF.show()
# Out:
# [Stage 48:=============================>                            (1 + 1) / 2]
# +----------------+------------+---------------------+
# | locus          | alleles    | <expr>              |
# +----------------+------------+---------------------+
# | locus<GRCh38>  | array<str> | array<float64>      |
# +----------------+------------+---------------------+
# | chr22:22890203 | ["A","T"]  | [9.58e-01,4.17e-02] |
# +----------------+------------+---------------------+

# %%
donor_mt0.entries().show()
# Out:
# [Stage 50:=============================>                            (1 + 1) / 2]
# +----------------+------------+------+-------------------+------------+
# | locus          | alleles    | rsid | n_unsplit_alleles | mixed_site |
# +----------------+------------+------+-------------------+------------+
# | locus<GRCh38>  | array<str> | str  |             int32 |       bool |
# +----------------+------------+------+-------------------+------------+
# | chr22:22890203 | ["A","T"]  | NA   |                 2 |      False |
# +----------------+------------+------+-------------------+------------+
#
# +---------+-----------+---------+----------+-------------+--------------+
# | a_index | was_split |    qual | filters  | allele_type | AS_MQRankSum |
# +---------+-----------+---------+----------+-------------+--------------+
# |   int32 |      bool | float64 | set<str> | str         |      float64 |
# +---------+-----------+---------+----------+-------------+--------------+
# ...

# %%
p = hl.plot.histogram(donor_mt.variant_qc.AF[1])
show(p)

# %%
mt = mt.semi_join_rows(donor_mt.rows())

# %%
mt.cols().show()
# Out:
# 2022-09-03 07:56:28 Hail: WARN: cols(): Resulting column table is sorted by 'col_key'.
#     To preserve matrix table column order, first unkey columns with 'key_cols_by()'
# +------------+----------------+--------------------+-------------------+
# | s          | meta.is_female | meta.chr20_mean_dp | meta.chrX_mean_dp |
# +------------+----------------+--------------------+-------------------+
# | str        |           bool |            float64 |           float64 |
# +------------+----------------+--------------------+-------------------+
# | "CPG10017" |          False |           5.23e+01 |          2.44e+01 |
# | "CPG10025" |          False |           5.24e+01 |          2.49e+01 |
# | "CPG10033" |           True |           3.96e+01 |          3.66e+01 |
# | "CPG10041" |          False |           4.07e+01 |          1.91e+01 |
# | "CPG10058" |          False |           4.03e+01 |          1.80e+01 |
# | "CPG10066" |          False |           3.60e+01 |          1.69e+01 |
# ...
