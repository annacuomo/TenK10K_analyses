# %%
mydir = "/share/ScratchGeneral/anncuo/sc-integration-workshop/"
# list.files(mydir,"DE")

# %%
list.files(mydir,"new_DE")
# Out:
# [1] "new_DE_results_B_intermediate.csv" "new_DE_results_B_naive.csv"
# [3] "new_DE_results_CD14_Mono.csv"      "new_DE_results_CD16_Mono.csv"
# [5] "new_DE_results_CD8_Naive.csv"      "new_DE_results_CD8_TEM.csv"

# %%
myfile = paste0(mydir,'new_DE_results_CD8_TEM.csv')
df1 = read.csv(myfile, row.names=1)

# %%
nrow(df1[df1$p_val_adj < 0.05,])
df1[df1$p_val_adj < 0.05,]
# Out:
# [1] 16
#               p_val         avg_log2FC  pct.1 pct.2 p_val_adj
# TTTY15        5.911574e-145 -156.705689 0.409 0.981 1.935331e-140
# EIF1AY        2.079267e-141 -207.270386 0.545 0.993 6.807103e-137
# UTY           1.073794e-138  -70.777363 0.400 0.969 3.515386e-134
# DDX3Y         1.679571e-138 -338.948651 0.604 0.995 5.498580e-134
# KDM5D         2.381871e-135 -113.077014 0.409 0.974 7.797770e-131
# ZFY           6.179471e-125  -32.550029 0.170 0.875 2.023035e-120
# USP9Y         1.026579e-123  -56.706317 0.230 0.913 3.360815e-119
# TMSB4Y         8.232691e-64   -6.280984 0.044 0.507  2.695218e-59
# EIF1AX         1.380837e-12         Inf 0.995 0.998  4.520584e-08
# ZRSR2          8.084158e-11  135.202243 0.988 0.990  2.646592e-06
# TXLNG          2.119212e-09   77.370443 0.966 0.935  6.937878e-05
# EIF2S3         3.010884e-08  174.765409 0.998 1.000  9.857033e-04
# KDM5C          1.366043e-07   21.422962 0.931 0.913  4.472150e-03
# ...

# %%
rownames(df[df$p_val_adj < 0.05,])
# Out:
#  [1] "EIF1AY"        "DDX3Y"         "UTY"           "TTTY15"
#  [5] "KDM5D"         "USP9Y"         "ZFY"           "ZRSR2"
#  [9] "JPX"           "PRKX"          "RP11-706O15.1" "ZFX"
# [13] "CA5B"          "KDM5C"         "TXLNG"         "SYAP1"
# [17] "DDX3X"         "KDM6A"         "CXorf38"       "ITGA4"
# [21] "FUNDC1"        "C1orf228"      "FAM13A"        "PNPLA4"
# [25] "AP1S2"         "ZNF568"        "CHD6"          "BCL2"
# [29] "SOCS2"         "ACSF3"         "RABGAP1L"      "TMEM156"
# [33] "UBQLN2"        "TMEM259"       "RSAD1"         "OFD1"
# [37] "ARHGAP9"       "ACTN1"         "TMIGD2"        "FAM46A"
# [41] "SMG9"          "SLC40A1"       "UBA1"          "ESF1"
# [45] "RP11-220I1.1"  "CYTH1"         "CD96"          "PLD3"
# [49] "CENPC"         "LYRM4"         "LTA4H"         "BBX"
# [53] "RSF1"          "ANKZF1"        "PDE4B"         "RLIM"
# [57] "AKAP9"         "ADTRP"         "FAM172A"       "LETMD1"
# [61] "AL592284.1"

# %%
install.packages("enrichR")
# Out:
# also installing the dependency ‘rjson’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(enrichR)
setEnrichrSite("Enrichr")
dbs <- listEnrichrDbs()
# run the over over-representation analysis in kegg
enrich_pw <- enrichr(rownames(df[df$p_val_adj < 0.05,]), 'KEGG_2021_Human')
# Out:
# Welcome to enrichR
# Checking connection ...
#
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is available!
#
# WormEnrichr ...
# Connection is available!
#
# YeastEnrichr ...
# Connection is available!
#
# FishEnrichr ...
# Connection is available!
#
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!
# Uploading data to Enrichr... Done.
#   Querying KEGG_2021_Human... Done.
# Parsing results... Done.

# %%
enrich_pw
# Out:
# $KEGG_2021_Human
#                                                    Term Overlap    P.value
# 1                                        Focal adhesion   3/201 0.02349820
# 2                                           Shigellosis   3/246 0.03926238
# 3   Parathyroid hormone synthesis, secretion and action   2/106 0.04158724
# 4                  Leukocyte transendothelial migration   2/114 0.04739877
# 5                                   Nitrogen metabolism    1/17 0.05062347
# 6                               Fatty acid biosynthesis    1/18 0.05352153
# 7                            JAK-STAT signaling pathway   2/162 0.08755836
# 8                                           Hepatitis B   2/162 0.08755836
# 9           Protein processing in endoplasmic reticulum   2/171 0.09593659
# 10                                          Ferroptosis    1/41 0.11782630
# 11                                 Viral carcinogenesis   2/203 0.12739247
# ...

# %%
enrich_pw <- enrichr(rownames(df1[df1$p_val_adj < 0.05,]), 'KEGG_2021_Human')
# Out:
# Uploading data to Enrichr... Done.
#   Querying KEGG_2021_Human... Done.
# Parsing results... Done.

# %%
enrich_pw
# Out:
# $KEGG_2021_Human
#                               Term Overlap      P.value Adjusted.P.value
# 1                    RNA transport   3/186 0.0004053851      0.003243081
# 2                       Amoebiasis   1/102 0.0785799328      0.201131901
# 3                   Chagas disease   1/102 0.0785799328      0.201131901
# 4             Dopaminergic synapse   1/132 0.1005659503      0.201131901
# 5 Regulation of actin cytoskeleton   1/218 0.1608981091      0.207656517
# 6        Calcium signaling pathway   1/240 0.1757107052      0.207656517
# 7                Parkinson disease   1/249 0.1816994528      0.207656517
# 8           Olfactory transduction   1/440 0.2995722536      0.299572254
#   Old.P.value Old.Adjusted.P.value Odds.Ratio Combined.Score
# 1           0                    0  24.969735     195.030436
# 2           0                    0  13.124092      33.382952
# 3           0                    0  13.124092      33.382952
# ...

# %%
enrich_pw <- enrichr(rownames(df0[df0$p_val_adj < 0.05,]), 'KEGG_2021_Human')
# Out:
# Uploading data to Enrichr... Done.
#   Querying KEGG_2021_Human... Done.
# Parsing results... Done.

# %%
enrich_pw
# Out:
# $KEGG_2021_Human
#                                                    Term Overlap    P.value
# 1                                   Nitrogen metabolism    1/17 0.03594198
# 2                                           Hepatitis B   2/162 0.04742281
# 3                                          Tuberculosis   2/180 0.05719159
# 4                Various types of N-glycan biosynthesis    1/39 0.08058702
# 5                                 N-Glycan biosynthesis    1/50 0.10214577
# 6                            Hedgehog signaling pathway    1/56 0.11369616
# 7                                             Mitophagy    1/68 0.13636317
# 8                                    Retinol metabolism    1/68 0.13636317
# 9                 RIG-I-like receptor signaling pathway    1/70 0.14008555
# 10                                p53 signaling pathway    1/73 0.14563974
# 11                                        Leishmaniasis    1/77 0.15299086
# ...

# %%
rownames(df1[df1$p_val_adj < 0.05,])[rownames(df1[df1$p_val_adj < 0.05,]) %in% ifn]
# Out:
# character(0)

# %%
# CD4+ KLRB1+ T cell (CD4EM/TEMRA)

# %%
myfile = paste0(mydir,'DE_results_CD4pos_KLRB1pos_T_cell.csv')
df = read.csv(myfile, row.names=1)
head(df)
# Out:
#        p_val         avg_log2FC pct.1 pct.2 p_val_adj
# EIF1AY 1.567678e-140       -Inf 0.388 0.971 5.132265e-136
# DDX3Y  2.344251e-135 -584.10674 0.411 0.983 7.674608e-131
# UTY    1.431618e-131  -58.23210 0.294 0.942 4.686832e-127
# TTTY15 3.028032e-131  -80.46481 0.288 0.942 9.913172e-127
# KDM5D  3.283761e-119  -38.13127 0.271 0.916 1.075038e-114
# USP9Y  6.435807e-100  -24.91558 0.120 0.769  2.106955e-95

# %%
rownames(df0[df0$p_val_adj < 0.05,])
# Out:
#  [1] "EIF1AY"        "TTTY15"        "UTY"           "DDX3Y"
#  [5] "KDM5D"         "ZFY"           "USP9Y"         "TTTY14"
#  [9] "ZRSR2"         "JPX"           "KDM6A"         "TSIX"
# [13] "ZFX"           "PRKX"          "TXLNG"         "RP11-706O15.1"
# [17] "SYAP1"         "SMC1A"         "CXorf38"       "DDX3X"
# [21] "KDM5C"         "CA5B"          "HDHD1"         "PNPLA4"
# [25] "FUNDC1"        "RP11-706O15.3" "FAM13A"        "FCGR3A"
# [29] "TMIGD2"        "MMEL1"         "RAB34"         "ADTRP"
# [33] "OFD1"          "AC074289.1"    "ALG13"         "HEMGN"
# [37] "NR1H2"         "FCRL6"         "TMEM242"       "BCL2"
# [41] "PATL2"         "USP9X"         "USP11"

# %%
rownames(df[df$p_val_adj < 0.05,])
# Out:
#  [1] "EIF1AY"        "DDX3Y"         "UTY"           "TTTY15"
#  [5] "KDM5D"         "USP9Y"         "ZFY"           "ZRSR2"
#  [9] "JPX"           "PRKX"          "RP11-706O15.1" "ZFX"
# [13] "CA5B"          "KDM5C"         "TXLNG"         "SYAP1"
# [17] "DDX3X"         "KDM6A"         "CXorf38"       "ITGA4"
# [21] "FUNDC1"        "C1orf228"      "FAM13A"        "PNPLA4"
# [25] "AP1S2"         "ZNF568"        "CHD6"          "BCL2"
# [29] "SOCS2"         "ACSF3"         "RABGAP1L"      "TMEM156"
# [33] "UBQLN2"        "TMEM259"       "RSAD1"         "OFD1"
# [37] "ARHGAP9"       "ACTN1"         "TMIGD2"        "FAM46A"
# [41] "SMG9"          "SLC40A1"       "UBA1"          "ESF1"
# [45] "RP11-220I1.1"  "CYTH1"         "CD96"          "PLD3"
# [49] "CENPC"         "LYRM4"         "LTA4H"         "BBX"
# [53] "RSF1"          "ANKZF1"        "PDE4B"         "RLIM"
# [57] "AKAP9"         "ADTRP"         "FAM172A"       "LETMD1"
# [61] "AL592284.1"

# %%
rownames(df0[df0$p_val_adj < 0.05,])[rownames(df0[df0$p_val_adj < 0.05,]) %in% ifn]
# Out:
# character(0)

# %%
rownames(df[df$p_val_adj < 0.05,])[rownames(df[df$p_val_adj < 0.05,]) %in% ifn]
# Out:
# [1] "PDE4B"

# %%
ifn = c("ADAR","APOL6","ARID5B","ARL4A","AUTS2","B2M","BANK1","BATF2","BPGM","BST2","BTG1","C1R","C1S","CASP1","CASP3","CASP4","CASP7","CASP8","CCL2","CCL5","CCL7","CD274","CD38","CD40","CD69","CD74","CD86","CDKN1A","CFB","CFH","CIITA","CMKLR1","CMPK2","CMTR1","CSF2RB","CXCL10","CXCL11","CXCL9","DDX58","DDX60","DHX58","EIF2AK2","EIF4E3","EPSTI1","FAS","FCGR1A","FGL2","FPR1","GBP4","GBP6","GCH1","GPR18","GZMA","HELZ2","HERC6","HIF1A","HLA-A","HLA-B","HLA-DMA","HLA-DQA1","HLA-DRB1","HLA-G","ICAM1","IDO1","IFI27","IFI30","IFI35","IFI44","IFI44L","IFIH1","IFIT1","IFIT2","IFIT3","IFITM2","IFITM3","IFNAR2","IL10RA","IL15","IL15RA","IL18BP","IL2RB","IL4R","IL6","IL7","IRF1","IRF2","IRF4","IRF5","IRF7","IRF8","IRF9","ISG15","ISG20","ISOC1","ITGB7","JAK2","KLRK1","LAP3","LATS2","LCP2","LGALS3BP","LY6E","LYSMD2","MARCHF1","METTL7B","MT2A","MTHFD2","MVP","MX1","MX2","MYD88","NAMPT","NCOA3","NFKB1","NFKBIA","NLRC5","NMI","NOD1","NUP93","OAS2","OAS3","OASL","OGFR","P2RY14","PARP12","PARP14","PDE4B","PELI1","PFKP","PIM1","PLA2G4A","PLSCR1","PML","PNP","PNPT1","PSMA2","PSMA3","PSMB10","PSMB2","PSMB8","PSMB9","PSME1","PSME2","PTGS2","PTPN1","PTPN2","PTPN6","RAPGEF6","RBCK1","RIPK1","RIPK2","RNF213","RNF31","RSAD2","RTP4","SAMD9L","SAMHD1","SECTM1","SELP","SERPING1","SLAMF7","SLC25A28","SOCS1","SOCS3","SOD2","SP110","SPPL2A","SRI","SSPN","ST3GAL5","ST8SIA4","STAT1","STAT2","STAT3","STAT4","TAP1","TAPBP","TDRD7","TNFAIP2","TNFAIP3","TNFAIP6","TNFSF10","TOR1B","TRAFD1","TRIM14","TRIM21","TRIM25","TRIM26","TXNIP","UBE2L6","UPP1","USP18","VAMP5","VAMP8","VCAM1","WARS1","XAF1","XCL1","ZBP1","ZNFX1")

# %%
nrow(df[df$p_val_adj < 0.05,])
df[df$p_val_adj < 0.005,]
# Out:
# [1] 61
#               p_val         avg_log2FC  pct.1 pct.2 p_val_adj
# EIF1AY        1.567678e-140        -Inf 0.388 0.971 5.132265e-136
# DDX3Y         2.344251e-135 -584.106743 0.411 0.983 7.674608e-131
# UTY           1.431618e-131  -58.232102 0.294 0.942 4.686832e-127
# TTTY15        3.028032e-131  -80.464808 0.288 0.942 9.913172e-127
# KDM5D         3.283761e-119  -38.131270 0.271 0.916 1.075038e-114
# USP9Y         6.435807e-100  -24.915578 0.120 0.769  2.106955e-95
# ZFY            1.787658e-91   -2.960284 0.080 0.690  5.852434e-87
# ZRSR2          2.340670e-30    6.871728 0.986 0.978  7.662886e-26
# JPX            4.908948e-26  -18.456061 0.979 0.940  1.607091e-21
# PRKX           8.995047e-22        -Inf 0.988 0.959  2.944798e-17
# RP11-706O15.1  2.959379e-19   15.222584 0.812 0.637  9.688415e-15
# ZFX            5.898245e-19   14.432073 0.956 0.873  1.930967e-14
# CA5B           4.692376e-17   44.892212 0.972 0.952  1.536190e-12
# ...

# %%
# CD8+ LTB+ T cell (CD8Naive/CM)

# %%
myfile = paste0(mydir,'DE_results_CD8pos_LTBpos_T_cell.csv')
df0 = read.csv(myfile, row.names=1)
head(df0)
# Out:
#        p_val         avg_log2FC pct.1 pct.2 p_val_adj
# EIF1AY 1.832686e-151       -Inf 0.651 1.000 5.999846e-147
# TTTY15 8.697343e-149 -132.56227 0.552 0.995 2.847336e-144
# UTY    4.592369e-145  -86.98454 0.533 0.993 1.503450e-140
# DDX3Y  6.609388e-143 -519.27001 0.653 0.998 2.163782e-138
# KDM5D  9.535037e-138  -73.56198 0.519 0.988 3.121580e-133
# ZFY    8.053197e-121  -33.58895 0.207 0.887 2.636456e-116

# %%
nrow(df0[df0$p_val_adj < 0.05,])
df0[df0$p_val_adj < 0.05,]
# Out:
# [1] 43
#               p_val         avg_log2FC  pct.1 pct.2 p_val_adj
# EIF1AY        1.832686e-151        -Inf 0.651 1.000 5.999846e-147
# TTTY15        8.697343e-149 -132.562267 0.552 0.995 2.847336e-144
# UTY           4.592369e-145  -86.984539 0.533 0.993 1.503450e-140
# DDX3Y         6.609388e-143 -519.270014 0.653 0.998 2.163782e-138
# KDM5D         9.535037e-138  -73.561977 0.519 0.988 3.121580e-133
# ZFY           8.053197e-121  -33.588950 0.207 0.887 2.636456e-116
# USP9Y         4.845378e-116  -32.254695 0.288 0.909 1.586280e-111
# TTTY14         3.160332e-64  -15.444204 0.046 0.512  1.034630e-59
# ZRSR2          1.060726e-34  166.246451 0.998 0.995  3.472603e-30
# JPX            8.158585e-33  146.601911 1.000 0.993  2.670958e-28
# KDM6A          3.173927e-27    2.296735 0.958 0.861  1.039080e-22
# TSIX           4.186849e-26    8.840956 0.568 0.260  1.370691e-21
# ZFX            1.494274e-23    6.900925 0.998 0.983  4.891953e-19
# ...

# %%
library(Seurat)
library(dplyr)

# %%
# Seurat object
myfile = "/share/ScratchGeneral/anncuo/sc-integration-workshop/donor_celltyoe_summed.csv"
df = read.csv(myfile, row.names=1, header=F)
head(df)
# Out:
#              V2                     V3
#              1_1_CD4+ KLRB1- T cell 1_1_CD4+ KLRB1+ T cell
# MIR1302-10   0                      0
# FAM138A      0                      0
# OR4F5        0                      0
# RP11-34P13.7 0                      0
# RP11-34P13.8 0                      0
#              V4                    V5
#              1_1_CD4+ SOX4+ T cell 1_1_CD8+ GNLY+ NKG7+ T cell
# MIR1302-10   0                     0
# FAM138A      0                     0
# OR4F5        0                     0
# RP11-34P13.7 0                     1.71828182845905
# RP11-34P13.8 0                     0
#              V6                   V7                     V8
#              1_1_CD8+ LTB+ T cell 1_1_CD8+ S100B+ T cell 1_1_Dendritic cell
# MIR1302-10   0                    0                      0
# FAM138A      0                    0                      0
# OR4F5        0                    0                      0
# ...

# %%
samples = gsub("\\+","pos",gsub("\\-","neg",gsub(" ","_",df[1,])))
head(samples)
# Out:
# [1] "1_1_CD4pos_KLRB1neg_T_cell"        "1_1_CD4pos_KLRB1pos_T_cell"
# [3] "1_1_CD4pos_SOX4pos_T_cell"         "1_1_CD8pos_GNLYpos_NKG7pos_T_cell"
# [5] "1_1_CD8pos_LTBpos_T_cell"          "1_1_CD8pos_S100Bpos_T_cell"

# %%
colnames(df) = samples
df = df[-1,]
dim(df)
df[1:5,1:5]
# Out:
# [1] 32738 14321
#              1_1_CD4pos_KLRB1neg_T_cell 1_1_CD4pos_KLRB1pos_T_cell
# MIR1302-10   0                          0
# FAM138A      0                          0
# OR4F5        0                          0
# RP11-34P13.7 0                          0
# RP11-34P13.8 0                          0
#              1_1_CD4pos_SOX4pos_T_cell 1_1_CD8pos_GNLYpos_NKG7pos_T_cell
# MIR1302-10   0                         0
# FAM138A      0                         0
# OR4F5        0                         0
# RP11-34P13.7 0                         1.71828182845905
# RP11-34P13.8 0                         0
#              1_1_CD8pos_LTBpos_T_cell
# MIR1302-10   0
# FAM138A      0
# OR4F5        0
# RP11-34P13.7 0
# RP11-34P13.8 0

# %%
nrow(df)
# Out:
# [1] 32738

# %%
df = as.matrix(df)
df1 = df[rowSums(df[])>0,]
# Out:
# Error in base::rowSums(x, na.rm = na.rm, dims = dims, ...): 'x' must be numeric
# Traceback:
#
# 1. rowSums(df[])
# 2. rowSums(df[])
# 3. base::rowSums(x, na.rm = na.rm, dims = dims, ...)

# %%
nrow(df1)
head(df1)

# %%
celltypes = c("CD4+ KLRB1- T cell","CD4+ KLRB1+ T cell","CD4+ SOX4+ T cell","CD8+ GNLY+ NKG7+ T cell",
              "CD8+ LTB+ T cell","CD8+ S100B+ T cell","XCL1- NK","XCL1+ NK","IgJ+ B cell","TCL1A- FCER2- B cell",
              "TCL1A+ FCER2+ B cell","Monocyte CD14+","Monocyte FCGR3A+","Dendritic cell")
length(celltypes)

# %%
celltypes = gsub("\\+","pos",gsub("\\-","neg",gsub(" ","_",celltypes)))
head(celltypes)

# %%
## Covariates
mydir = "/share/ScratchGeneral/anncuo/OneK1K/"
covs_filename =  paste0(mydir,"/covariates.tsv")
df_covs = read.csv(covs_filename, sep="\t")
head(df_covs)
# Out:
#   sampleid  SEX PCA1        PCA2         PCA3        PCA4        PCA5
# 1 1_1       2    0.02775250 -0.000592955  0.00757785 -0.01409290  0.009323330
# 2 10_10     2    0.02052560  0.040040200 -0.01847820  0.03658380 -0.014617600
# 3 1000_1001 2    0.01081720 -0.004233600  0.00537891 -0.02058190 -0.027539500
# 4 1001_1002 2    0.01211940  0.000788658 -0.00671328 -0.01969960 -0.000180694
# 5 1002_1003 1   -0.05739470 -0.019243700  0.00442424  0.00619121 -0.010877400
# 6 1003_1004 2    0.00532722  0.008837440 -0.01299120  0.00997544 -0.024854800
#   PCA6
# 1  0.031375400
# 2  0.013474100
# 3 -0.039861100
# 4  0.037322600
# 5 -0.013743000
# 6  0.000188687

# %%
## Age covariates
age_filename =  paste0(mydir,"/age_covariate.tsv")
df_age = read.csv(age_filename, sep="\t")
colnames(df_age)[1] = "sampleid"
head(df_age)
# Out:
#   sampleid age
# 1 1_1      65
# 2 2_2      48
# 3 3_3      53
# 4 4_4      48
# 5 5_5      41
# 6 6_6      79

# %%
age_sex = inner_join(df_age, df_covs)
head(age_sex)
# Out:
# Joining, by = "sampleid"
#   sampleid age SEX PCA1        PCA2         PCA3        PCA4
# 1 1_1      65  2    0.02775250 -0.000592955  0.00757785 -0.014092900
# 2 2_2      48  2   -0.04813530 -0.056674100 -0.01547420 -0.000729391
# 3 3_3      53  2    0.01369180 -0.046308100 -0.00584410  0.026565000
# 4 4_4      48  2    0.01780390  0.046411400 -0.02508330  0.015125200
# 5 6_6      79  2   -0.01165420  0.015232400  0.01065710 -0.071689000
# 6 7_7      74  2    0.00233242  0.022173500  0.02882250  0.004397390
#   PCA5        PCA6
# 1  0.00932333  0.03137540
# 2  0.00027473  0.01116000
# 3 -0.00435940  0.03093290
# 4  0.02318960 -0.00741249
# 5 -0.05411840  0.00316309
# 6  0.07210630 -0.02177460

# %%
nrow(age_sex)
# Out:
# [1] 982

# %%
for (celltype in celltypes){
    print(celltype)
    samples = colnames(df)[grep(celltype,colnames(df))]
    counts = df[,samples]
    samples = gsub(paste0("_",celltype),"",samples)
    meta_subset = age_sex[age_sex$sampleid %in% colnames(counts),]
    rownames(meta_subset) = meta_subset$sampleid
    colnames(counts) = samples
    sce = CreateSeuratObject(counts, meta.data = meta_subset)
    Idents(object = sce, cells = female_donors) <- "Female"
    mat = FindMarkers(sce, ident.1 = "Female", min.pct = 0.5)
    write.csv(mat,paste0("/share/ScratchGeneral/anncuo/sc-integration-workshop/DE_results_",celltype,".csv"))
}
# Out:
# [1] "CD4pos_KLRB1neg_T_cell"
# [1] "CD4pos_KLRB1pos_T_cell"
# [1] "CD4pos_SOX4pos_T_cell"
# [1] "CD8pos_GNLYpos_NKG7pos_T_cell"
# [1] "CD8pos_LTBpos_T_cell"
# [1] "CD8pos_S100Bpos_T_cell"
# [1] "XCL1neg_NK"
# [1] "XCL1pos_NK"
# [1] "IgJpos_B_cell"
# [1] "TCL1Aneg_FCER2neg_B_cell"
# [1] "TCL1Apos_FCER2pos_B_cell"
# [1] "Monocyte_CD14pos"
# [1] "Monocyte_FCGR3Apos"
# [1] "Dendritic_cell"

# %%
dim(df)
# Out:
# [1] 32738 14321

# %%
head(df)
# Out:
#              1_1_CD4pos_KLRB1neg_T_cell 1_1_CD4pos_KLRB1pos_T_cell
# MIR1302-10   0                          0
# FAM138A      0                          0
# OR4F5        0                          0
# RP11-34P13.7 0                          0
# RP11-34P13.8 0                          0
# AL627309.1   0                          0
#              1_1_CD4pos_SOX4pos_T_cell 1_1_CD8pos_GNLYpos_NKG7pos_T_cell
# MIR1302-10   0                         0
# FAM138A      0                         0
# OR4F5        0                         0
# RP11-34P13.7 0                         1.71828182845905
# RP11-34P13.8 0                         0
# AL627309.1   0                         0
#              1_1_CD8pos_LTBpos_T_cell 1_1_CD8pos_S100Bpos_T_cell
# MIR1302-10   0                        0
# FAM138A      0                        0
# OR4F5        0                        0
# RP11-34P13.7 0                        0
# RP11-34P13.8 0                        0
# AL627309.1   0                        0
# ...

# %%
celltype = 'CD4pos_KLRB1neg_T_cell'
samples = colnames(df)[grep(celltype,colnames(df))]
# samples = samples[!(is.na(samples))]
# head(samples)

# %%
# head(df)

# %%
counts = df[,samples]
# counts = df[,colnames(df) %in% samples]

# %%
dim(counts)
# Out:
# [1] 32738   981

# %%
celltype
# Out:
# [1] "CD4pos_KLRB1neg_T_cell"

# %%
samples = gsub(paste0("_",celltype),"",samples)
head(samples)
# Out:
# [1] "1_1"       "10_10"     "1000_1001" "1001_1002" "1002_1003" "1003_1004"

# %%
meta_subset = age_sex[age_sex$sampleid %in% colnames(counts),]
rownames(meta_subset) = meta_subset$sampleid
colnames(counts) = samples
sce = CreateSeuratObject(counts, meta.data = meta_subset)

# %%
sce
# Out:
# An object of class Seurat
# 32738 features across 981 samples within 1 assay
# Active assay: RNA (32738 features, 0 variable features)

# %%
# female_donors
head(colnames(sce))
# Out:
# [1] "1_1"       "10_10"     "1000_1001" "1001_1002" "1002_1003" "1003_1004"

# %%
Idents(object = sce, cells = female_donors) <- "Female"
mat = FindMarkers(sce, ident.1 = "Female", min.pct = 0.5)
mat
# Out:
#               p_val         avg_log2FC  pct.1 pct.2 p_val_adj
# TTTY15        2.889796e-155 -412.66776  0.788 1.000 9.460613e-151
# ZFY           6.564180e-155 -101.92714  0.377 0.990 2.148981e-150
# EIF1AY        4.428982e-154       -Inf  0.887 1.000 1.449960e-149
# KDM5D         9.544578e-153 -262.67633  0.742 1.000 3.124704e-148
# UTY           2.265282e-152 -299.27567  0.781 1.000 7.416080e-148
# DDX3Y         5.798785e-152       -Inf  0.919 1.000 1.898406e-147
# USP9Y         1.628109e-151 -101.27892  0.542 0.993 5.330102e-147
# TMSB4Y        2.330046e-106  -13.54062  0.113 0.786 7.628104e-102
# TTTY14         5.074242e-91  -25.63996  0.145 0.748  1.661205e-86
# TSIX           1.736938e-77   11.84272  0.920 0.481  5.686386e-73
# RP11-424G14.1  3.600507e-68   -5.11717  0.065 0.565  1.178734e-63
# ZRSR2          5.622250e-54  447.28958  1.000 0.998  1.840612e-49
# JPX            6.703924e-50   89.67947  1.000 1.000  2.194731e-45
# ...

# %%
write.csv(mat,paste0("/share/ScratchGeneral/anncuo/sc-integration-workshop/DE_results_",celltype,".csv"))

# %%
# mono_cd14_samples = colnames(counts)[grep("Monocyte.CD14",colnames(counts))]
DC_samples = colnames(counts)[grep("Dendritic.cell",colnames(counts))]

# %%
counts_DC = df[,DC_samples]
ncol(counts_DC)
head(counts_DC)
# Out:
# [1] 968
#              X1_1_Dendritic.cell X10_10_Dendritic.cell
# MIR1302-10   0                   0
# FAM138A      0                   0
# OR4F5        0                   0
# RP11-34P13.7 0                   0
# RP11-34P13.8 0                   0
# AL627309.1   0                   0
#              X1000_1001_Dendritic.cell X1001_1002_Dendritic.cell
# MIR1302-10   0                         0
# FAM138A      0                         0
# OR4F5        0                         0
# RP11-34P13.7 0                         0
# RP11-34P13.8 0                         0
# AL627309.1   0                         0
#              X1002_1003_Dendritic.cell X1003_1004_Dendritic.cell
# MIR1302-10   0                         0.000000
# FAM138A      0                         0.000000
# OR4F5        0                         0.000000
# RP11-34P13.7 0                         0.000000
# RP11-34P13.8 0                         0.000000
# AL627309.1   0                         1.718282
# ...

# %%
colnames(counts_DC) = gsub("X","",gsub("\\.","",gsub("_Dendritic.cell","",colnames(counts_DC))))
counts_DC[1:5,1:5]
# Out:
#              1_1 10_10 1000_1001 1001_1002 1002_1003
# MIR1302-10   0   0     0         0         0
# FAM138A      0   0     0         0         0
# OR4F5        0   0     0         0         0
# RP11-34P13.7 0   0     0         0         0
# RP11-34P13.8 0   0     0         0         0

# %%
# colnames(counts_mono_cd14) = gsub("X","",gsub("\\.","",gsub("_Monocyte.CD14","",colnames(counts_mono_cd14))))
# counts_mono_cd14[1:5,1:5]

# %%
nrow(age_sex)
meta_subset = age_sex[age_sex$sampleid %in% colnames(counts_mono_cd14),]
rownames(meta_subset) = meta_subset$sampleid
nrow(meta_subset)
head(meta_subset)
# Out:
# [1] 982
# [1] 968
#     sampleid age SEX PCA1        PCA2         PCA3        PCA4
# 1_1 1_1      65  2    0.02775250 -0.000592955  0.00757785 -0.014092900
# 2_2 2_2      48  2   -0.04813530 -0.056674100 -0.01547420 -0.000729391
# 3_3 3_3      53  2    0.01369180 -0.046308100 -0.00584410  0.026565000
# 4_4 4_4      48  2    0.01780390  0.046411400 -0.02508330  0.015125200
# 6_6 6_6      79  2   -0.01165420  0.015232400  0.01065710 -0.071689000
# 7_7 7_7      74  2    0.00233242  0.022173500  0.02882250  0.004397390
#     PCA5        PCA6
# 1_1  0.00932333  0.03137540
# 2_2  0.00027473  0.01116000
# 3_3 -0.00435940  0.03093290
# 4_4  0.02318960 -0.00741249
# 6_6 -0.05411840  0.00316309
# 7_7  0.07210630 -0.02177460

# %%
length(colnames(counts_mono_cd14))
# Out:
# [1] 968

# %%
sce_DC = CreateSeuratObject(counts_DC, meta.data = meta_subset)
# Out:
# Warning message in CreateSeuratObject.default(counts_DC, meta.data = meta_subset):
# “Some cells in meta.data not present in provided counts matrix”

# %%
female_donors = age_sex[age_sex$SEX==2,"sampleid"]
length(female_donors)
head(female_donors)
# Out:
# [1] 565
# [1] "1_1" "2_2" "3_3" "4_4" "6_6" "7_7"

# %%
Idents(object = sce, cells = female_donors) <- "Female"

# %%
Idents(sce)
# Out:
#           1_1         10_10     1000_1001     1001_1002     1002_1003
#        Female        Female        Female        Female SeuratProject
#     1003_1004     1004_1005     1005_1006     1006_1007     1007_1008
#        Female        Female SeuratProject SeuratProject        Female
#     1008_1009     1009_1010       101_101     1010_1011     1012_1013
# SeuratProject        Female        Female        Female        Female
#     1014_1015     1015_1016     1016_1017     1018_1019     1019_1020
#        Female SeuratProject SeuratProject        Female SeuratProject
#       102_102     1020_1021     1021_1022     1022_1023     1023_1024
#        Female        Female        Female        Female        Female
#     1024_1025     1025_1026     1026_1027     1027_1028     1028_1029
#        Female        Female        Female        Female        Female
#     1029_1030     1030_1031     1031_1032     1032_1033     1033_1034
# ...

# %%
mat = FindMarkers(sce, ident.1 = "Female", min.pct = 0.5)

# %%
# mat_mono_CD14 = mat

# %%
head(mat)

# %%
nrow(mat)
nrow(mat[mat$p_val_adj<0.05,])
# Out:
# [1] 5970
# [1] 4

# %%
dds <- DESeqDataSetFromMatrix(cluster_counts, 
                              colData = cluster_metadata, 
                              design = ~ group_id)

# %%
dds <- DESeq(dds)
