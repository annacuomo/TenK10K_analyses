# %%
smf_all = "/share/ScratchGeneral/anncuo/OneK1K/input_files_CellRegMap/smf_Bcells_noplasma.csv"
fvf_all = "/share/ScratchGeneral/anncuo/OneK1K/input_files_CellRegMap/fvf_Bcell_eqtls.csv"

# %%
smf_df = read.csv(smf_all, row.names=1)
head(smf_df)
# Out:
#   phenotype_sample_id genotype_individual_id individual_long
# 1 AAACCTGCAACGATCT-1  687                    686_687
# 2 AAACCTGGTCAGAATA-1  693                    692_693
# 3 AAACGGGAGCGTCAAG-1  693                    692_693
# 4 AAACGGGAGGGAACGG-1  691                    690_691
# 5 AAACGGGCAGTTCATG-1  683                    682_683
# 6 AAACGGGGTCCCTACT-1  693                    692_693

# %%
smf_small = head(smf_df)
smf_small
# Out:
#   phenotype_sample_id genotype_individual_id individual_long
# 1 AAACCTGCAACGATCT-1  687                    686_687
# 2 AAACCTGGTCAGAATA-1  693                    692_693
# 3 AAACGGGAGCGTCAAG-1  693                    692_693
# 4 AAACGGGAGGGAACGG-1  691                    690_691
# 5 AAACGGGCAGTTCATG-1  683                    682_683
# 6 AAACGGGGTCCCTACT-1  693                    692_693

# %%
smf_small_filename = "/share/ScratchGeneral/anncuo/OneK1K/input_files_CellRegMap/test_inputs/head_smf_Bcells.csv"
write.csv(smf_small, smf_small_filename)

# %%
smf_less_small = head(smf_df,100)
smf_less_small
# Out:
#     phenotype_sample_id genotype_individual_id individual_long
# 1   AAACCTGCAACGATCT-1  687                    686_687
# 2   AAACCTGGTCAGAATA-1  693                    692_693
# 3   AAACGGGAGCGTCAAG-1  693                    692_693
# 4   AAACGGGAGGGAACGG-1  691                    690_691
# 5   AAACGGGCAGTTCATG-1  683                    682_683
# 6   AAACGGGGTCCCTACT-1  693                    692_693
# 7   AAACGGGGTTGCGCAC-1  684                    683_684
# 8   AAAGATGCAAGCCTAT-1  689                    688_689
# 9   AAAGATGGTTATGCGT-1  687                    686_687
# 10  AAAGATGTCATGCATG-1  688                    687_688
# 11  AAAGCAAAGACAGACC-1  691                    690_691
# 12  AAAGCAAAGATTACCC-1  686                    685_686
# 13  AAAGCAACACGTGAGA-1  691                    690_691
# 14  AAAGCAAGTGCGATAG-1  691                    690_691
# 15  AAAGCAAGTGTTCTTT-1  688                    687_688
# 16  AAAGTAGAGAGGGATA-1  685                    684_685
# ...

# %%
smf_less_small_filename = "/share/ScratchGeneral/anncuo/OneK1K/input_files_CellRegMap/test_inputs/head_100_smf_Bcells.csv"
write.csv(smf_less_small, smf_less_small_filename)

# %%
fvf_df = read.csv(fvf_all, row.names=1)
head(fvf_df)
# Out:
#   feature       snp_id       chrom
# 1 RP11-298J20.3 10:126644482 10
# 2 PPA1          10:71963608  10
# 3 GDI2          10:5855403   10
# 4 OPTN          10:13160035  10
# 5 MGMT          10:131279791 10
# 6 VDAC2         10:76970613  10

# %%
fvf_df$gene = fvf_df$feature

# %%
fvf_small = fvf_df[2:7,]
fvf_small
# Out:
#   feature snp_id       chrom gene
# 2 PPA1    10:71963608  10    PPA1
# 3 GDI2    10:5855403   10    GDI2
# 4 OPTN    10:13160035  10    OPTN
# 5 MGMT    10:131279791 10    MGMT
# 6 VDAC2   10:76970613  10    VDAC2
# 7 VCL     10:75913033  10    VCL

# %%
fvf_small_filename = "/share/ScratchGeneral/anncuo/OneK1K/input_files_CellRegMap/test_inputs/head_fvf_Bcell_eqtls.csv"
write.csv(fvf_small, fvf_small_filename)
